# %%
import pandas as pd
from requests_html import HTMLSession

# %%
# A-1   单一页面
url = "https://www.liepin.com/zhaopin/?key=短视频运营"
session = HTMLSession()
r = session.get( url )

# 先取特定元素, 精准打击其子后辈
主要元素 = r.html.xpath( \
    '//ul[@class="sojob-list"]/li')

# 预期是一个元素的列表？
#print (主要元素[0].xpath('//div[contains(@class,"sojob-item-main")]'))
#print (主要元素[0].xpath('//div[contains(@class,"job-info")]/h3/a'))
#print (主要元素[3].xpath('//div[contains(@class,"job-info")]/p/a'))
#print (主要元素[3].xpath('//div[contains(@class,"job-info")]/p/span[@class="text-warning"]'))
#print (主要元素[3].xpath('//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span'))
#print (主要元素[3].xpath('//div[contains(@class,"job-info")]/p/time/@title'))
#print (主要元素[0].xpath('//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a'))

# 作为xpath字典，键为我要抓的牛肉名称，值为xpath
dict_xpaths={ 
    'text': {
        'edu':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]',
        '经验':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span',
        '薪水':    '//div[contains(@class,"job-info")]/p/span[@class="text-warning"]', 
        '时间':    '//div[contains(@class,"job-info")]/p/time/@title', 
        '职称':    '//div[contains(@class,"job-info")]/h3/a', 
        '公司地点': '//div[contains(@class,"job-info")]/p/a',
        '公司名称': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
    },
    'text_content': {
    },
    'href': {
        '链结':    '//div[contains(@class,"job-info")]/h3/a', 
        '公司URL': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
    }
}

def get_e_text_content(_xpath_):
    # 高级列表推导
    暂存结果 = [e.xpath(_xpath_)[0].lxml.text_content() for e in 主要元素]
    return(暂存结果)

def get_e_text(_xpath_):
    # 高级列表推导
    暂存结果 = ["".join([x.strip() if type(x) is str else x.text.strip() for x in e.xpath(_xpath_)]) for e in 主要元素]
    return(暂存结果)

def get_e_href(_xpath_):
    # 高级列表推导
    暂存结果 = [list(e.xpath(_xpath_, first=True).absolute_links)[0] \
               if len(e.xpath(_xpath_, first=True).absolute_links) >= 1  \
               else "" for e in 主要元素]
    return(暂存结果)

# 只对主要元素下进行.xpath取值
数据字典 = dict()

数据字典 = {k:get_e_text_content(v) for k,v in dict_xpaths['text_content'].items()}
数据字典.update({k:get_e_text(v) for k,v in dict_xpaths['text'].items()})
数据字典.update({k:get_e_href(v) for k,v in dict_xpaths['href'].items()})

[len(v) for k,v in 数据字典.items()]

数据 = pd.DataFrame(数据字典)
#数据.to_excel("20春_Web数据挖掘_week03_liepin.xlsx", sheet_name="搜查结果")
数据
# Out:
#          edu     经验          薪水           时间                  职称     公司地点  \
# 0      大专及以上   3-5年  13-16k·12薪  2020年07月02日         内容运营经理（短视频）   广州-天河区
# 1      大专及以上   经验不限    4-6k·12薪  2020年07月07日               短视频运营  石家庄-裕华区
# 2       统招本科   经验不限  18-23k·12薪  2020年07月07日             短视频赛道运营
# 3      本科及以上   3-5年  26-35k·12薪  2020年07月07日             短视频运营总监       杭州
# 4      大专及以上   3-5年    6-8k·13薪  2020年07月07日               短视频运营   广州-越秀区
# 5      本科及以上   一年以下   8-12k·12薪  2020年07月07日               短视频运营
# 6      大专及以上   经验不限   8-15k·12薪  2020年07月07日               短视频运营   深圳-南山区
# 7       学历不限   3-5年  15-30k·12薪  2020年07月07日             短视频内容运营       北京
# 8      大专及以上   经验不限    4-6k·12薪  2020年07月07日             短视频电商运营   深圳-龙华区
# 9      大专及以上   1-3年   6-10k·12薪  2020年07月07日            短视频全平台运营    广州-西关
# 10     大专及以上   1-3年    5-8k·12薪  2020年07月07日               短视频运营       上海
# 11      学历不限   1-3年   8-15k·12薪  2020年07月07日            短视频运营负责人       徐州
# 12     本科及以上   3-5年  15-25k·12薪  2020年07月07日          短视频创意策划/运营       北京
# 13      学历不限   1-3年    4-8k·12薪  2020年07月07日               短视频运营   郑州-金水区
# 14     本科及以上  10年以上  40-60k·12薪  2020年07月07日            短视频运营负责人    上海-江湾
# 15     大专及以上   3-5年   8-12k·12薪  2020年07月07日               短视频运营
# 16     本科及以上   一年以下   8-14k·12薪  2020年07月07日  短视频运营专员 (MJ000415)
# 17     大专及以上   3-5年   8-10k·12薪  2020年07月07日               短视频运营    武汉-徐东
# 18  中专/中技及以上   经验不限    4-6k·12薪  2020年07月07日               短视频运营       汕尾
# 19      学历不限   经验不限    4-5k·12薪  2020年07月07日             短视频运营助理
# 20     本科及以上   1-3年   8-15k·12薪  2020年07月07日               短视频运营
# 21     大专及以上   1-3年    5-8k·12薪  2020年07月07日             短视频运营编剧   广州-从化区
# 28   https://www.liepin.com/company/9730683/
# 29   https://www.liepin.com/company/9891561/
# 30  https://www.liepin.com/company/12152071/
# 31   https://www.liepin.com/company/9785861/
# 32  https://www.liepin.com/company/10207805/
# 33  https://www.liepin.com/company/10207805/
# 34  https://www.liepin.com/company/10207805/
# 35  https://www.liepin.com/company/10207805/
# 36  https://www.liepin.com/company/10207805/
# 37  https://www.liepin.com/company/12145515/
# 38   https://www.liepin.com/company/9161191/
# 39   https://www.liepin.com/company/8628501/

# %% [markdown]
# ### xpath解析翻页

# %%
# 单一页面
url = "https://www.liepin.com/zhaopin/?key=短视频运营"
session = HTMLSession()
r = session.get( url )

# %%
# xpath 解析翻页a/@href
xpath_翻页a = '//div[@class="pagerbar"]/a' # 有disabled, current等href是javascript
xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'
print (r.html.xpath(xpath_翻页a)) # 物件

href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
#print (href_列表)

文字_列表 = [x.text for x in r.html.xpath(xpath_翻页a)]
#print (文字_列表)

href_字典 = {x.text:x.xpath('//@href')[0]  for x in r.html.xpath(xpath_翻页a)}
print (href_字典)
# Out:
# [<Element 'a' href='/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=1'>, <Element 'a' href='/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=2'>, <Element 'a' href='/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=3'>, <Element 'a' href='/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=4'>, <Element 'a' href='/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=1'>, <Element 'a' class=('last',) href='/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=9' title='末页'>]
# {'2': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=1', '3': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=2', '4': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=3', '5': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=4', '下一页': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=1', '': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=9'}

# %% [markdown]
# ### 构建参数模板

# %%
# 建构参数模板：找到关键参数及参数结构
from urllib.parse import urlparse, parse_qs
import pandas as pd
from IPython.display import display, HTML

# 总体目标：输入 href_列表, 建构出参数字典

# urlparse 解析后丢入数据框
df = pd.DataFrame([ urlparse(x) for x in href_列表])
df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])

display(df)
print(df.nunique())
display(df_qs)
print(df_qs.nunique())

df_qs.curPage
df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int))
# Out:
#   scheme netloc       path params  \
# 0                /zhaopin/
# 1                /zhaopin/
# 2                /zhaopin/
# 3                /zhaopin/
# 4                /zhaopin/
# 5                /zhaopin/
#
#                                                query fragment
# 0  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 1  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 2  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 3  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 4  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 5  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# scheme      1
# netloc      1
# path        1
# params      1
# query       5
# fragment    1
# dtype: int64
#   pageSize     sortFlag    key                                          siTag  \
# 0       40  °radeFlag=0  短视频运营  icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw
# 1       40  °radeFlag=0  短视频运营  icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw
# 2       40  °radeFlag=0  短视频运营  icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw
# 3       40  °radeFlag=0  短视频运营  icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw
# 4       40  °radeFlag=0  短视频运营  icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw
# 5       40  °radeFlag=0  短视频运营  icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw
#
#           d_sfrom                            d_ckId d_curPage d_pageSize  \
# 0  search_unknown  375622397438f45e120a2d401e5740aa         0         40
# 1  search_unknown  375622397438f45e120a2d401e5740aa         0         40
# 2  search_unknown  375622397438f45e120a2d401e5740aa         0         40
# 3  search_unknown  375622397438f45e120a2d401e5740aa         0         40
# 4  search_unknown  375622397438f45e120a2d401e5740aa         0         40
# 5  search_unknown  375622397438f45e120a2d401e5740aa         0         40
#
#                            d_headId curPage
# 0  375622397438f45e120a2d401e5740aa       1
# 1  375622397438f45e120a2d401e5740aa       2
# 2  375622397438f45e120a2d401e5740aa       3
# 3  375622397438f45e120a2d401e5740aa       4
# 4  375622397438f45e120a2d401e5740aa       1
# 5  375622397438f45e120a2d401e5740aa       9
# pageSize      1
# sortFlag      1
# key           1
# siTag         1
# d_sfrom       1
# d_ckId        1
# d_curPage     1
# d_pageSize    1
# d_headId      1
# curPage       5
# dtype: int64

# %% [markdown]
# ### 建构参数模板：curPage

# %%
# 建构参数模板：找到关键参数及参数结构

def parse_url_qs_for_curPage (url):
    six_parts = urlparse(url) 
    out = parse_qs(six_parts.query)
    return (out)

# 取一例做模板
参数模板 = parse_url_qs_for_curPage(href_列表[0])
print (参数模板)

print (href_字典)
# Out:
# {'pageSize': ['40'], 'sortFlag': ['°radeFlag=0'], 'key': ['短视频运营'], 'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['375622397438f45e120a2d401e5740aa'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['375622397438f45e120a2d401e5740aa'], 'curPage': ['1']}
# {'2': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=1', '3': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=2', '4': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=3', '5': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=4', '下一页': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=1', '': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E7%9F%AD%E8%A7%86%E9%A2%91%E8%BF%90%E8%90%A5&siTag=icgOLfoBEcDFRuwEbVrpTQ%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=375622397438f45e120a2d401e5740aa&d_curPage=0&d_pageSize=40&d_headId=375622397438f45e120a2d401e5740aa&curPage=9'}

# %%
# 建构参数模板生成器：keyword curPage
def 参数模板生成(keyword, curPage):
    参数 = 参数模板.copy()
    参数['curPage'] = curPage
    参数['keyword'] = keyword
    return (参数)

参数_keyword_短视频运营_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['短视频运营']) \
    for i,v in href_字典.items()\
    }

# print(参数_keyword_用户体验_curPage) # 只生成本页有的额外翻页URL, 并没有推估到&curPage=9,也没有这页

print (df_qs.curPage_int.min()) # 最小值只有1
print (df_qs.curPage_int.max()) # 最大值只有9

# 应该是 0 (本页)....9(最大值)

参数_keyword_短视频运营_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['短视频运营']) \
    for i in range(0,df_qs.curPage_int.max()+1)\
    }
参数_keyword_短视频运营_curPage
# Out:
# 1
# 9
# {0: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [0],
#   'keyword': ['短视频运营']},
#  1: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [1],
#   'keyword': ['短视频运营']},
#  2: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [2],
#   'keyword': ['短视频运营']},
#  3: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [3],
#   'keyword': ['短视频运营']},
#  4: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [4],
#   'keyword': ['短视频运营']},
#  5: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [5],
#   'keyword': ['短视频运营']},
#  6: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [6],
#   'keyword': ['短视频运营']},
#  7: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [7],
#   'keyword': ['短视频运营']},
#  8: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [8],
#   'keyword': ['短视频运营']},
#  9: {'pageSize': ['40'],
#   'sortFlag': ['°radeFlag=0'],
#   'key': ['短视频运营'],
#   'siTag': ['icgOLfoBEcDFRuwEbVrpTQ~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['375622397438f45e120a2d401e5740aa'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['375622397438f45e120a2d401e5740aa'],
#   'curPage': [9],
#   'keyword': ['短视频运营']}}

# %% [markdown]
# ### 爬亦有道

# %%
# requests_liepin
session = HTMLSession()

def requests_liepin( url, params):
    r = session.get( url , params = payload)

    # 先取特定元素, 精准打击其子后辈
    主要元素 = r.html.xpath( '//ul[@class="sojob-list"]/li')

    # 作为xpath字典，键为我要抓的牛肉名称，值为xpath
    dict_xpaths={ 
        'text': {
            'edu':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]',
            '经验':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span',
            '薪水':    '//div[contains(@class,"job-info")]/p/span[@class="text-warning"]', 
            '时间':    '//div[contains(@class,"job-info")]/p/time/@title', 
            '职称':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司地点': '//div[contains(@class,"job-info")]/p/a',
            '公司名称': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        },
        'text_content': {
        },
        'href': {
            '链结':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司URL': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        }
    }

    def get_e_text_content(_xpath_):
        # 高级列表推导
        暂存结果 = [e.xpath(_xpath_)[0].lxml.text_content() for e in 主要元素]
        return(暂存结果)

    def get_e_text(_xpath_):
        # 高级列表推导
        暂存结果 = ["".join([x.strip() if type(x) is str else x.text.strip() for x in e.xpath(_xpath_)]) for e in 主要元素]
        return(暂存结果)

    def get_e_href(_xpath_):
        # 高级列表推导
        暂存结果 = [list(e.xpath(_xpath_, first=True).absolute_links)[0] \
                   if len(e.xpath(_xpath_, first=True).absolute_links) >= 1  \
                   else "" for e in 主要元素]
        return(暂存结果)

    # 只对主要元素下进行.xpath取值
    数据字典 = dict()

    数据字典 = {k:get_e_text_content(v) for k,v in dict_xpaths['text_content'].items()}
    数据字典.update({k:get_e_text(v) for k,v in dict_xpaths['text'].items()})
    数据字典.update({k:get_e_href(v) for k,v in dict_xpaths['href'].items()})

    数据 = pd.DataFrame(数据字典)
    #数据.to_excel("20春_Web数据挖掘_week03_liepin.xlsx", sheet_name="搜查结果")
    return (数据)

# %%
# %%time

import time
from random import random

url = "https://www.liepin.com/zhaopin/"

list_df = list()
for k,v in 参数_keyword_短视频运营_curPage.items():
    payload = v
    df = requests_liepin( url, params = payload)
    time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
    df = df.assign (curPage = k)  # 区分  curPage
    list_df.append(df)

df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

# 上周C-4   输出
df_all.to_excel("20春_Web数据挖掘_final_liepin_翻页.xlsx",\
                sheet_name="短视频运营")
# Out:
# Wall time: 56.8 s

# %%
# %%time
# B-3 多个页面+多个关键词
import time
from random import random

url = "https://www.liepin.com/zhaopin/"
xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'

keywords = ['短视频运营','短视频编导']
list_df = list()

## 第一页试探有多长的页面
for key in keywords:
    payload = 参数模板生成(keyword=[key], curPage=['0'])
    df = requests_liepin( url, params = payload)
    href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
    df = pd.DataFrame([ urlparse(x) for x in href_列表])
    df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])
    df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数
    长度 = df_qs.curPage_int.max()+1
    参数_keyword_X_curPage = { 
        i:参数模板生成(curPage = [i], \
                      keyword = [key]) \
        for i in range(0,长度)\
        }
    #print (参数_keyword_X_curPage)
    print (key,长度)
    
    for k,v in 参数_keyword_X_curPage.items():
        payload = v
        df = requests_liepin( url, params = payload)
        time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
        df = df.assign (keyword = key)  # 区分  keyword    
        df = df.assign (curPage = k)  # 区分  curPage    
        list_df.append(df)
        
df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

df_all.to_excel("双关键词_Web数据挖掘_final_liepin_翻页.xlsx",\
                sheet_name="_".join(keywords))
# Out:
# 短视频运营 10
# 短视频编导 10
# Wall time: 1min 59s

# %%
# %%time
# B-3 多个页面+多个关键词
import time
from random import random

url = "https://www.liepin.com/zhaopin/"
xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'

keywords = ['短视频运营','广州','深圳']
list_df = list()

## 第一页试探有多长的页面
for key in keywords:
    payload = 参数模板生成(keyword=[key], curPage=['0'])
    df = requests_liepin( url, params = payload)
    href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
    df = pd.DataFrame([ urlparse(x) for x in href_列表])
    df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])
    df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数
    长度 = df_qs.curPage_int.max()+1
    参数_keyword_X_curPage = { 
        i:参数模板生成(curPage = [i], \
                      keyword = [key]) \
        for i in range(0,长度)\
        }
    #print (参数_keyword_X_curPage)
    print (key,长度)
    
    for k,v in 参数_keyword_X_curPage.items():
        payload = v
        df = requests_liepin( url, params = payload)
        time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
        df = df.assign (keyword = key)  # 区分  keyword    
        df = df.assign (curPage = k)  # 区分  curPage    
        list_df.append(df)
        
df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

df_all.to_excel("职位和城市_Web数据挖掘_final_liepin_翻页.xlsx",\
                sheet_name="_".join(keywords))
# Out:
# 短视频运营 10
# 广州 10
# 深圳 10
# Wall time: 2min 42s
